# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Lane 2 - Refresh / Content Opportunity Scoring.
#
# Reason: This lane perfectly synergizes with my data mining background to build a high-ROI predictive ranking system instead of just pulling basic stats. By engineering an actionable review queue with clear reason codes, it optimizes human bandwidth and targets the lowest-hanging fruit for content updates.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: optimize the triage workflow by identifying which pages should be reviewed first for a content refresh, expansion, or pruning.
#
# Action: A human reviewer acts on this ranked queue, using the provided reason codes to decide if they should update the page, fix the metadata, or just monitor it.
#
# Cost of a Wrong Call: A bad recommendation completely wastes the human reviewer's limited bandwidth on false alarms—like a page dropping due to normal seasonality or random noise. That means we fumble the bag by missing out on saving a page that is actually bleeding real traffic.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
from pathlib import Path

root = Path("..").resolve()
repo = Path("../..").resolve()
csv_path = Path("../..") / "data" / "raw" / "content_refresh_anonymized.csv"

df = pd.read_csv(csv_path) 
total_pages = len(df)
declining_demand = len(df[(df['trend_direction'] == 'down') & (df['impressions_90d'] >= 100)])
low_ctr = len(df[(df['impressions_90d'] >= 500) & (df['ctr'] < 0.5)])

print(f"Total content items in starter set: {total_pages}")
print(f"Pages actively declining with demand: {declining_demand}")
print(f"High-visibility pages with low CTR (< 0.5): {low_ctr}")
# Out:
# Total content items in starter set: 30000
# Pages actively declining with demand: 13152
# High-visibility pages with low CTR (< 0.5): 14245

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What I can claim: I can confidently make observed, directional claims (e.g., "we observed this pattern," or "this metric suggests an opportunity"). My model is strictly a decision-support tool designed to rank and prioritize pages for human review based on historical evidence and safe data.
#
# What I can't claim: I will absolutely not claim causal proof—like saying a specific content refresh directly caused a traffic recovery—because this is observational data without a controlled experiment. I will also never claim to be "predicting Google" or proving Google's algorithm factors. We are analyzing evidence and surface-level signals, not hacking the mainframe.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
